# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import  RandomizedSearchCV
from scipy.stats import uniform, randint

# %%
pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_columns')

# %%
seasons_df=pd.read_pickle('data/seasons_HA_df.pkl')

# %%
seasons_df['Date'].is_monotonic_increasing
# Out:
# True

# %%
seasons_df[seasons_df['season']=='season17']
# Out:
#           Date        HomeTeam      AwayTeam FTR  AwayWin   Draw  HomeWin  \
# 0   2017-08-11         Arsenal     Leicester   H    False  False     True
# 1   2017-08-12        Brighton      Man City   A     True  False    False
# 2   2017-08-12         Chelsea       Burnley   A     True  False    False
# 3   2017-08-12  Crystal Palace  Huddersfield   A     True  False    False
# 4   2017-08-12         Everton         Stoke   H    False  False     True
# ..         ...             ...           ...  ..      ...    ...      ...
# 375 2018-05-13       Newcastle       Chelsea   H    False  False     True
# 376 2018-05-13     Southampton      Man City   A     True  False    False
# 377 2018-05-13         Swansea         Stoke   A     True  False    False
# 378 2018-05-13       Tottenham     Leicester   H    False  False     True
# 379 2018-05-13        West Ham       Everton   H    False  False     True
#
#      home.matchNumber home.daysSince home.total.win home.total.draw  \
# 0                   1            NaT           <NA>            <NA>
# 1                   1            NaT           <NA>            <NA>
# 2                   1            NaT           <NA>            <NA>
# 3                   1            NaT           <NA>            <NA>
# 4                   1            NaT           <NA>            <NA>
# ..                ...            ...            ...             ...
# 375                38         4 days       0.297297        0.216216
# 376                38         5 days       0.189189        0.405405
# 377                38         5 days       0.216216        0.243243
# 378                38         4 days       0.594595        0.216216
# 379                38         3 days       0.243243        0.324324
#
#     home.total.loss home.total.goals home.total.conceded  \
# 0              <NA>             <NA>                <NA>
# 1              <NA>             <NA>                <NA>
# 2              <NA>             <NA>                <NA>
# 3              <NA>             <NA>                <NA>
# 4              <NA>             <NA>                <NA>
# ..              ...              ...                 ...
# 375        0.486486         0.972973             1.27027
# 376        0.405405              1.0            1.486486
# 377        0.540541          0.72973            1.459459
# 378        0.189189         1.864865            0.864865
# 379        0.432432         1.216216            1.810811
#
#     home.total.half_goals home.total.half_conceded home.total.shots  \
# 0                    <NA>                     <NA>             <NA>
# 1                    <NA>                     <NA>             <NA>
# 2                    <NA>                     <NA>             <NA>
# 3                    <NA>                     <NA>             <NA>
# 4                    <NA>                     <NA>             <NA>
# ..                    ...                      ...              ...
# 375              0.405405                 0.513514        11.702703
# 376              0.432432                 0.756757        11.972973
# 377              0.243243                 0.648649         8.378378
# 378              0.702703                 0.405405        16.432432
# 379              0.513514                 0.702703         9.675676
#
#     home.total.shots_against home.total.shots_target  \
# 0                       <NA>                    <NA>
# 1                       <NA>                    <NA>
# 2                       <NA>                    <NA>
# 3                       <NA>                    <NA>
# 4                       <NA>                    <NA>
# ..                       ...                     ...
# 375                12.783784                3.891892
# 376                12.972973                3.837838
# 377                14.324324                2.513514
# 378                 9.162162                5.702703
# 379                14.783784                3.486486
#
#     home.total.shots_against_target home.total.corners  \
# 0                              <NA>               <NA>
# 1                              <NA>               <NA>
# 2                              <NA>               <NA>
# 3                              <NA>               <NA>
# 4                              <NA>               <NA>
# ..                              ...                ...
# 375                        4.189189           4.405405
# 376                        4.540541           6.108108
# 377                        5.027027           3.891892
# 378                        3.162162           6.540541
# 379                        4.945946           4.189189
#
#     home.total.corners_conceded home.total.fouls home.total.fouls_other_team  \
# 0                          <NA>             <NA>                        <NA>
# 1                          <NA>             <NA>                        <NA>
# 2                          <NA>             <NA>                        <NA>
# 3                          <NA>             <NA>                        <NA>
# 4                          <NA>             <NA>                        <NA>
# ..                          ...              ...                         ...
# 375                    5.972973        10.756757                   10.243243
# 376                    5.108108        11.027027                   10.459459
# 377                     5.27027         9.864865                   10.945946
# 378                    4.216216        10.135135                   10.648649
# 379                    5.459459         9.972973                   12.162162
#
#     home.total.yellows home.total.reds  home.last3.win  home.last3.draw  \
# 0                 <NA>            <NA>             NaN              NaN
# 1                 <NA>            <NA>             NaN              NaN
# 2                 <NA>            <NA>             NaN              NaN
# 3                 <NA>            <NA>             NaN              NaN
# 4                 <NA>            <NA>             NaN              NaN
# ..                 ...             ...             ...              ...
# 375           1.405405        0.054054        0.000000         0.000000
# 376           1.621622        0.054054        0.666667         0.333333
# 377           1.351351        0.027027        0.000000         0.000000
# 378           1.297297        0.054054        0.666667         0.000000
# 379           1.945946        0.054054        0.333333         0.333333
#
#      home.last3.loss  home.last3.goals  home.last3.conceded  \
# 0                NaN               NaN                  NaN
# 1                NaN               NaN                  NaN
# 2                NaN               NaN                  NaN
# 3                NaN               NaN                  NaN
# 4                NaN               NaN                  NaN
# ..               ...               ...                  ...
# 375         1.000000          0.333333             1.333333
# 376         0.000000          1.333333             0.666667
# 377         1.000000          0.000000             1.000000
# 378         0.333333          1.000000             0.333333
# 379         0.333333          1.000000             1.333333
#
#      home.last3.half_goals  home.last3.half_conceded  home.last3.shots  \
# 0                      NaN                       NaN               NaN
# 1                      NaN                       NaN               NaN
# 2                      NaN                       NaN               NaN
# 3                      NaN                       NaN               NaN
# 4                      NaN                       NaN               NaN
# ..                     ...                       ...               ...
# 375               0.000000                  1.000000         13.333333
# 376               0.333333                  0.333333         12.666667
# 377               0.000000                  0.666667         11.000000
# 378               0.333333                  0.000000         14.000000
# 379               0.666667                  0.666667          8.666667
#
#      home.last3.shots_against  home.last3.shots_target  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 375                 10.333333                 2.000000
# 376                 11.333333                 6.333333
# 377                 12.333333                 3.000000
# 378                 12.000000                 5.000000
# 379                 16.000000                 2.000000
#
#      home.last3.shots_against_target  home.last3.corners  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ..                               ...                 ...
# 375                         5.666667            4.666667
# 376                         4.333333            5.000000
# 377                         5.333333            4.666667
# 378                         3.000000            6.333333
# 379                         5.000000            1.333333
#
#      home.last3.corners_conceded  home.last3.fouls  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ..                           ...               ...
# 375                     3.000000          9.000000
# 376                     6.000000         13.000000
# 377                     6.333333         10.000000
# 378                     3.000000         11.000000
# 379                     7.000000          8.666667
#
#      home.last3.fouls_other_team  home.last3.yellows  home.last3.reds  \
# 0                            NaN                 NaN              NaN
# 1                            NaN                 NaN              NaN
# 2                            NaN                 NaN              NaN
# 3                            NaN                 NaN              NaN
# 4                            NaN                 NaN              NaN
# ..                           ...                 ...              ...
# 375                    10.666667            1.666667         0.000000
# 376                    10.666667            3.333333         0.333333
# 377                    11.333333            2.333333         0.000000
# 378                    10.333333            1.333333         0.000000
# 379                    10.333333            1.000000         0.000000
#
#      away.matchNumber away.daysSince away.total.win away.total.draw  \
# 0                   1            NaT           <NA>            <NA>
# 1                   1            NaT           <NA>            <NA>
# 2                   1            NaT           <NA>            <NA>
# 3                   1            NaT           <NA>            <NA>
# 4                   1            NaT           <NA>            <NA>
# ..                ...            ...            ...             ...
# 375                38         4 days       0.567568        0.189189
# 376                38         4 days       0.837838        0.108108
# 377                38         8 days       0.162162        0.324324
# 378                38         4 days       0.324324        0.297297
# 379                38         8 days       0.351351         0.27027
#
#     away.total.loss away.total.goals away.total.conceded  \
# 0              <NA>             <NA>                <NA>
# 1              <NA>             <NA>                <NA>
# 2              <NA>             <NA>                <NA>
# 3              <NA>             <NA>                <NA>
# 4              <NA>             <NA>                <NA>
# ..              ...              ...                 ...
# 375        0.243243         1.675676            0.945946
# 376        0.054054         2.837838             0.72973
# 377        0.513514         0.891892            1.810811
# 378        0.378378         1.405405            1.486486
# 379        0.378378         1.162162            1.486486
#
#     away.total.half_goals away.total.half_conceded away.total.shots  \
# 0                    <NA>                     <NA>             <NA>
# 1                    <NA>                     <NA>             <NA>
# 2                    <NA>                     <NA>             <NA>
# 3                    <NA>                     <NA>             <NA>
# 4                    <NA>                     <NA>             <NA>
# ..                    ...                      ...              ...
# 375              0.810811                 0.324324        16.216216
# 376              1.216216                 0.324324        17.594595
# 377              0.405405                 0.648649        10.108108
# 378              0.648649                 0.675676        10.972973
# 379              0.405405                 0.648649         9.351351
#
#     away.total.shots_against away.total.shots_target  \
# 0                       <NA>                    <NA>
# 1                       <NA>                    <NA>
# 2                       <NA>                    <NA>
# 3                       <NA>                    <NA>
# 4                       <NA>                    <NA>
# ..                       ...                     ...
# 375                 9.756757                5.891892
# 376                 6.216216                     7.0
# 377                14.918919                3.405405
# 378                12.864865                3.756757
# 379                14.243243                3.108108
#
#     away.total.shots_against_target away.total.corners  \
# 0                              <NA>               <NA>
# 1                              <NA>               <NA>
# 2                              <NA>               <NA>
# 3                              <NA>               <NA>
# 4                              <NA>               <NA>
# ..                              ...                ...
# 375                        3.081081           6.162162
# 376                         2.27027           7.351351
# 377                        5.648649           3.675676
# 378                        4.378378           5.378378
# 379                        4.837838           3.891892
#
#     away.total.corners_conceded away.total.fouls away.total.fouls_other_team  \
# 0                          <NA>             <NA>                        <NA>
# 1                          <NA>             <NA>                        <NA>
# 2                          <NA>             <NA>                        <NA>
# 3                          <NA>             <NA>                        <NA>
# 4                          <NA>             <NA>                        <NA>
# ..                          ...              ...                         ...
# 375                    4.189189         9.540541                   10.972973
# 376                    2.756757         9.027027                    9.675676
# 377                    7.432432        11.540541                    10.27027
# 378                     5.72973         9.513514                    9.675676
# 379                    5.567568        12.054054                   10.081081
#
#     away.total.yellows away.total.reds  away.last3.win  away.last3.draw  \
# 0                 <NA>            <NA>             NaN              NaN
# 1                 <NA>            <NA>             NaN              NaN
# 2                 <NA>            <NA>             NaN              NaN
# 3                 <NA>            <NA>             NaN              NaN
# 4                 <NA>            <NA>             NaN              NaN
# ..                 ...             ...             ...              ...
# 375           1.081081        0.108108        0.666667         0.333333
# 376           1.540541        0.054054        0.666667         0.333333
# 377           1.621622        0.027027        0.000000         0.666667
# 378           1.351351        0.135135        0.333333         0.000000
# 379           1.351351        0.081081        0.666667         0.333333
#
#      away.last3.loss  away.last3.goals  away.last3.conceded  \
# 0                NaN               NaN                  NaN
# 1                NaN               NaN                  NaN
# 2                NaN               NaN                  NaN
# 3                NaN               NaN                  NaN
# 4                NaN               NaN                  NaN
# ..               ...               ...                  ...
# 375         0.000000          1.000000             0.333333
# 376         0.000000          2.333333             0.666667
# 377         0.333333          0.666667             1.000000
# 378         0.666667          1.000000             2.666667
# 379         0.000000          1.333333             0.333333
#
#      away.last3.half_goals  away.last3.half_conceded  away.last3.shots  \
# 0                      NaN                       NaN               NaN
# 1                      NaN                       NaN               NaN
# 2                      NaN                       NaN               NaN
# 3                      NaN                       NaN               NaN
# 4                      NaN                       NaN               NaN
# ..                     ...                       ...               ...
# 375               0.666667                  0.000000         15.000000
# 376               1.333333                  0.666667         17.666667
# 377               0.666667                  0.000000          6.666667
# 378               0.333333                  1.000000         12.666667
# 379               0.333333                  0.000000          8.333333
#
#      away.last3.shots_against  away.last3.shots_target  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 375                  7.666667                 4.000000
# 376                  5.000000                 5.333333
# 377                 16.333333                 2.000000
# 378                 14.000000                 4.333333
# 379                  9.666667                 3.000000
#
#      away.last3.shots_against_target  away.last3.corners  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ..                               ...                 ...
# 375                         3.333333            4.666667
# 376                         2.333333            7.000000
# 377                         3.666667            2.000000
# 378                         6.333333            5.333333
# 379                         3.000000            3.333333
#
#      away.last3.corners_conceded  away.last3.fouls  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ..                           ...               ...
# 375                     0.666667          9.333333
# 376                     1.333333          8.333333
# 377                     8.000000         15.666667
# 378                     5.666667          8.000000
# 379                     4.666667         10.666667
#
#      away.last3.fouls_other_team  away.last3.yellows  away.last3.reds  \
# 0                            NaN                 NaN              NaN
# 1                            NaN                 NaN              NaN
# 2                            NaN                 NaN              NaN
# 3                            NaN                 NaN              NaN
# 4                            NaN                 NaN              NaN
# ..                           ...                 ...              ...
# 375                    10.666667            1.333333         0.000000
# 376                     5.333333            0.333333         0.000000
# 377                     8.000000            3.000000         0.000000
# 378                    10.666667            1.333333         0.333333
# 379                    10.666667            1.333333         0.000000
#
#     home.total.win.whenHome home.total.draw.whenHome home.total.loss.whenHome  \
# 0                      <NA>                     <NA>                     <NA>
# 1                      <NA>                     <NA>                     <NA>
# 2                      <NA>                     <NA>                     <NA>
# 3                      <NA>                     <NA>                     <NA>
# 4                      <NA>                     <NA>                     <NA>
# ..                      ...                      ...                      ...
# 375                0.388889                 0.222222                 0.388889
# 376                0.222222                 0.388889                 0.388889
# 377                0.333333                 0.166667                      0.5
# 378                0.666667                 0.222222                 0.111111
# 379                0.333333                 0.333333                 0.333333
#
#     away.total.win.whenAway away.total.draw.whenAway away.total.loss.whenAway  \
# 0                      <NA>                     <NA>                     <NA>
# 1                      <NA>                     <NA>                     <NA>
# 2                      <NA>                     <NA>                     <NA>
# 3                      <NA>                     <NA>                     <NA>
# 4                      <NA>                     <NA>                     <NA>
# ..                      ...                      ...                      ...
# 375                0.555556                 0.166667                 0.277778
# 376                0.833333                 0.111111                 0.055556
# 377                0.055556                 0.388889                 0.555556
# 378                0.277778                 0.277778                 0.444444
# 379                0.166667                 0.333333                      0.5
#
#        season
# 0    season17
# 1    season17
# 2    season17
# 3    season17
# 4    season17
# ..        ...
# 375  season17
# 376  season17
# 377  season17
# 378  season17
# 379  season17
#
# [380 rows x 86 columns]

# %%
#no nulls once all teams have played 4 games
seasons_df[(seasons_df['home.matchNumber']>=4) & (seasons_df['away.matchNumber']>=4)].isna().any().any()
# Out:
# True

# %%
seasons_df.drop(columns=['Date', 'HomeTeam', 'AwayTeam'], inplace=True)

# %%
label_encoder = LabelEncoder()
seasons_df['label'] = label_encoder.fit_transform(seasons_df['FTR'])

# %%
seasons_df['home.daysSince']=seasons_df['home.daysSince'].dt.days
seasons_df['away.daysSince']=seasons_df['away.daysSince'].dt.days

# %% [markdown]
# Make the train and test sets

# %%
#filtering out the matches before a team has played 3 matches that season
seasons_df=seasons_df.dropna()

# %%
train=seasons_df[~(seasons_df['season']=='season17')]
train=train.copy()
train.drop('season', axis=1, inplace=True)

# %%
# Calculate value counts for 'result' column
result_counts = train['FTR'].value_counts()

# Define the colors in the same order as the labels
color_mapping = {'A': '#FFA07A',  # Light salmon (matte orange)
                 'H': '#87CEEB',  # Sky blue (matte blue)
                 'D': '#90EE90'}  # Light green (matte green)
colors = [color_mapping[label] for label in result_counts.index]

# Plot pie chart
plt.figure(figsize=(4, 4))
plt.pie(result_counts, labels=result_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Match Results in England 17")
plt.show()

# %%
X_train=train.drop(['label','FTR'], axis=1)
y_train=train['label']

# %%
test=seasons_df[seasons_df['season']=='season17']
test=test.copy()
test.drop('season', axis=1, inplace=True)

# %%
# Calculate value counts for 'result' column
result_counts = test['FTR'].value_counts()

# Define the colors in the same order as the labels
color_mapping = {'A': '#FFA07A',  # Light salmon (matte orange)
                 'H': '#87CEEB',  # Sky blue (matte blue)
                 'D': '#90EE90'}  # Light green (matte green)
colors = [color_mapping[label] for label in result_counts.index]

# Plot pie chart
plt.figure(figsize=(4, 4))
plt.pie(result_counts, labels=result_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Match Results in England 17")
plt.show()

# %%
X_test=test.drop(['label', 'FTR'], axis=1)
y_test=test['label']

# %% [markdown]
# Scale the features

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.79087485, -0.13678418, -1.90927659, ..., -1.31080843,
#         -1.30118028,  2.29533816],
#        [-1.6943715 , -0.13678418, -1.90927659, ...,  3.12208961,
#         -1.30118028, -1.79533869],
#        [-1.6943715 , -0.13678418, -1.90927659, ..., -1.31080843,
#          3.60126752, -1.79533869],
#        ...,
#        [ 1.68324555, -0.7358801 , -0.77397462, ..., -1.06453632,
#          0.6053272 ,  0.47725956],
#        [ 1.68324555, -1.03542807,  1.21280383, ..., -0.07944786,
#          0.06061078,  0.02273991],
#        [ 1.68324555, -1.33497603, -0.63206188, ..., -0.57199209,
#          0.33296899,  0.24999973]])

# %% [markdown]
# ### RandomForest

# %%
# Step 4: Train a model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Step 5: Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 0.52

# %%
def evaluate_model(model, X_test, y_test, label_encoder):
    """
    Evaluate the model's performance using accuracy and a classification report.
    
    Parameters:
    model: The trained model
    X_test: Test features
    y_test: Actual labels for the test set
    label_encoder: The label encoder used to transform labels
    
    Returns:
    None
    """
    # Step 1: Make predictions
    y_pred = model.predict(X_test)
    
    # Step 2: Convert predicted numeric labels back to original labels
    y_pred_labels = label_encoder.inverse_transform(y_pred)
    
    # Step 3: Convert actual labels back to original labels
    y_test_labels = label_encoder.inverse_transform(y_test)
    
    # Step 4: Calculate and print accuracy
    accuracy = accuracy_score(y_test_labels, y_pred_labels)
    print(f"Model accuracy: {accuracy:.2f}")
    
    # Step 5: Generate and print classification report
    class_report = classification_report(y_test_labels, y_pred_labels)
    print("\nClassification Report:")
    print(class_report)

# %%
evaluate_model(model, X_test, y_test, label_encoder)
# Out:
# Model accuracy: 0.52
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.53      0.53      0.53       100
#            D       0.21      0.06      0.10        95
#            H       0.55      0.77      0.64       164
#
#     accuracy                           0.52       359
#    macro avg       0.43      0.45      0.42       359
# weighted avg       0.45      0.52      0.46       359

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test_labels, y_pred_labels)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Get feature importance from the model
feature_importances = model.feature_importances_

# Create a DataFrame to make it easier to read
feature_importance_df = pd.DataFrame({
    'Feature': train.drop(['label','FTR'], axis=1).columns,
    'Importance': feature_importances
})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print the feature importances
print(feature_importance_df)

## Plot the feature importance
#plt.figure(figsize=(10, 6))
#plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
#plt.xlabel('Importance')
#plt.title('Feature Importance')
#plt.show()
# Out:
#                      Feature  Importance
# 45          away.total.shots    0.024939
# 9           home.total.shots    0.024518
# 10  home.total.shots_against    0.022399
# 46  away.total.shots_against    0.022114
# 5           home.total.goals    0.020669
# ..                       ...         ...
# 21           home.last3.loss    0.003783
# 55            away.last3.win    0.003750
# 56           away.last3.draw    0.003749
# 35           home.last3.reds    0.002479
# 71           away.last3.reds    0.001942
#
# [78 rows x 2 columns]

# %%
# %%time
#Wall time: 6min 16s

param_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}
random_search = RandomizedSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, n_iter=20, verbose=1)
random_search.fit(X_train, y_train)
print(f'Best Parameters: {random_search.best_params_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 10, 'criterion': 'gini'}
# CPU times: user 6min 16s, sys: 658 ms, total: 6min 16s
# Wall time: 6min 16s

# %%
# Step 5: Evaluate the model
y_pred = random_search.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 0.53

# %%
evaluate_model(random_search, X_test, y_test, label_encoder)
# Out:
# Model accuracy: 0.53
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.56      0.50      0.53       100
#            D       0.17      0.01      0.02        95
#            H       0.53      0.85      0.65       164
#
#     accuracy                           0.53       359
#    macro avg       0.42      0.45      0.40       359
# weighted avg       0.44      0.53      0.45       359

# %% [markdown]
# ## XGBoost

# %%
# Train an XGBoost model
model = xgb.XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# Predict and evaluate
y_pred = model.predict(X_test)

# %%
evaluate_model(model, X_test, y_test, label_encoder)
# Out:
# Model accuracy: 0.51
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.47      0.46      0.47       100
#            D       0.38      0.24      0.29        95
#            H       0.57      0.70      0.62       164
#
#     accuracy                           0.51       359
#    macro avg       0.47      0.47      0.46       359
# weighted avg       0.49      0.51      0.49       359

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test_labels, y_pred_labels)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# %%time
#Wall time: 2min 37s

# Define the model
model = xgb.XGBClassifier(random_state=42)

# Define the parameter grid
param_grid = {
    'n_estimators': randint(100, 1000),          # Number of boosting rounds
    'learning_rate': uniform(0.01, 0.3),         # Learning rate
    'max_depth': randint(3, 10),                 # Max depth of tree
    'min_child_weight': randint(1, 10),          # Min child weight
    'subsample': uniform(0, 1),              # Fraction of samples used for each tree
    'colsample_bytree': uniform(0, 1),       # Fraction of features for each tree
    'gamma': uniform(0, 1),                      # Gamma (min loss reduction)
    'reg_alpha': uniform(0, 1),                  # L1 regularization term
    'reg_lambda': uniform(0, 1),                 # L2 regularization term
}

# Define the recall scorer for multiclass classification
#f1_scorer = make_scorer(f1_score, average='weighted')

# Initialize RandomizedSearchCV with the updated scorer
random_search = RandomizedSearchCV(model, param_distributions=param_grid, 
                                   n_iter=20, cv=5, scoring='accuracy',
                                   verbose=1, random_state=42, n_jobs=-1)

# Fit the model
random_search.fit(X_train, y_train)

# Output the best parameters
print(f'Best Parameters: {random_search.best_params_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'colsample_bytree': 0.6075448519014384, 'gamma': 0.17052412368729153, 'learning_rate': 0.029515477895583855, 'max_depth': 6, 'min_child_weight': 9, 'n_estimators': 415, 'reg_alpha': 0.5632882178455393, 'reg_lambda': 0.3854165025399161, 'subsample': 0.015966252220214194}
# CPU times: user 13.3 s, sys: 2.34 s, total: 15.7 s
# Wall time: 2min 37s

# %%
y_pred = random_search.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 0.54

# %%
evaluate_model(random_search, X_test, y_test, label_encoder)
# Out:
# Model accuracy: 0.54
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.57      0.51      0.54       100
#            D       0.39      0.12      0.18        95
#            H       0.55      0.80      0.65       164
#
#     accuracy                           0.54       359
#    macro avg       0.50      0.48      0.46       359
# weighted avg       0.51      0.54      0.49       359

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test_labels, y_pred_labels)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
